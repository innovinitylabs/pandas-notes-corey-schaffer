# %% [markdown]
# # 08 - Grouping and Aggregating - Analyzing and Exploring Your Data
#
# https://youtu.be/txMdrV1Ut64?si=SqRDKz2NN3VBccXA
#
# Notes by [Innovinitylabs](https://github.com/innovinitylabs)

# %%
import pandas as pd

#Setup for learning data

# people = {
#     "first": ["Corey", 'Jane', 'John', 'Ratan', 'Arjun', 'Pushpa', 'Rajinikanth'], 
#     "last": ["Schafer", 'Doe', 'Doe', 'Tata', 'Reddy', 'No Inti Peru', 'Rajinikanth'], 
#     "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com', 'Ratan@tata.com', 'Aready@email.com', 'thaggedhele@puspha.com', 'gmail@rajinikanth.com' ]
# }
# dft = pd.DataFrame(people)

# %% [markdown]
# ---

# %% [markdown]
# ### Setup for Real world data.
# ###### uncomment when in need to avoid conflicting code autocomplete suggestions

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent' )
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)

# %%
# pd.set_option('display.max_rows', 85)

# %% [markdown]
# ---
# ---
# ---

# %%
df.head(1)
# Out:
#                                         MainBranch Hobbyist OpenSourcer  \
# Respondent
# 1           I am a student who is learning to code      Yes       Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
#
#                                         Employment         Country Student  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom      No
#
#                               EdLevel UndergradMajor  \
# Respondent
# 1           Primary/elementary school            NaN
#
#                                                      EduOther OrgSize DevType  \
# Respondent
# 1           Taught yourself a new language, framework, or ...     NaN     NaN
#
#            YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot  \
# Respondent
# 1                  4         10          NaN       NaN    NaN      NaN
#
# ...

# %% [markdown]
# to get median salary

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">can do median for whole dataframe
#
#
#      error when using on 01 Oct 2023 `Pandas 2.1.1`
#
# </div>

# %%
# df.median()

# %% [markdown]
# ---

# %% [markdown]
# to get statistical overview of whole dataframe

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %% [markdown]
# count column is number of non NaN rows
#
# to count the individual values in the column we use `.value_counts()` method

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df['SocialMedia'].head(3)
# Out:
# Respondent
# 1      Twitter
# 2    Instagram
# 3       Reddit
# Name: SocialMedia, dtype: object

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts().head(3)
# Out:
# SocialMedia
# Reddit      14374
# YouTube     13830
# WhatsApp    13347
# Name: count, dtype: int64

# %% [markdown]
# to show it as <Mark>percentage</mark> we use `normalize=True`

# %%
df['SocialMedia'].value_counts(normalize=True).head(3)
# Out:
# SocialMedia
# Reddit      0.170233
# YouTube     0.163791
# WhatsApp    0.158071
# Name: proportion, dtype: float64

# %% [markdown]
# How do we get pupular social media sites based on country so we have to <mark>group by</mark> function

# %%
df['Country'].value_counts().head(2)
# Out:
# Country
# United States    20949
# India             9061
# Name: count, dtype: int64

# %%
country_grp = df.groupby(['Country'])
country_grp # <pandas.core.groupby.generic.DataFrameGroupBy object at 0x28d71c210>

# %%
country_grp.get_group('India').head(2)
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 8              I code primarily as a hobby      Yes
# 10          I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country Student  \
# Respondent
# 8           Not employed, but looking for work   India     NaN
# 10                          Employed full-time   India      No
#
#                                                 EdLevel  \
# Respondent
# 8              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10          Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
# ...

# %% [markdown]
# this is similar to running a filter in dataframe

# %%
filt = df['Country'] == 'India'
df[filt].head(2)
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 8              I code primarily as a hobby      Yes
# 10          I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
#
#                                     Employment Country Student  \
# Respondent
# 8           Not employed, but looking for work   India     NaN
# 10                          Employed full-time   India      No
#
#                                                 EdLevel  \
# Respondent
# 8              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10          Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
# ...

# %% [markdown]
# but `group by ` works for multiple countries

# %%
df[filt]['SocialMedia'].value_counts().head(3)
# Out:
# SocialMedia
# WhatsApp    2990
# YouTube     1820
# LinkedIn     955
# Name: count, dtype: int64

# %% [markdown]
# if we run this on dataframe `groupby` object, it will give result for all country groups
#
# > if we apply function on a single country it will return for specific country, but if we apply it on dataframe group by object it applies to the whole country groups***

# %%
country_grp['SocialMedia'].value_counts().head(11)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#              LinkedIn                     1
#              Twitter                      1
# Albania      WhatsApp                    18
#              Facebook                    16
#              Instagram                   13
#              YouTube                     10
# Name: count, dtype: int64

# %% [markdown]
# to get result for one country

# %%
country_grp['SocialMedia'].value_counts().loc['India'].head(3)
# Out:
# SocialMedia
# WhatsApp    2990
# YouTube     1820
# LinkedIn     955
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['India'].head(3)
# Out:
# SocialMedia
# WhatsApp    0.342379
# YouTube     0.208405
# LinkedIn    0.109355
# Name: proportion, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# we can use this to get mean median and related aggregate functions

# %%
country_grp['ConvertedComp'].median().head(3)
# Out:
# Country
# Afghanistan     6222.0
# Albania        10818.0
# Algeria         7878.0
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# to get a single country

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %% [markdown]
# To run multiple aggregate function

# %%
country_grp['ConvertedComp'].agg(['mean', 'median']).head(3)
# Out:
#                       mean   median
# Country
# Afghanistan  101953.333333   6222.0
# Albania       21833.700000  10818.0
# Algeria       34924.047619   7878.0

# %% [markdown]
# to get for single country

# %%
country_grp['ConvertedComp'].agg(['mean', 'median']).loc['Canada']
# Out:
# mean      134018.564909
# median     68705.000000
# Name: Canada, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# to get how many from a country uses python

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 8         True
# 10        True
# 15       False
# 50        True
# 65       False
#          ...
# 77339    False
# 79795     True
# 83862    False
# 84299     True
# 86012    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %% [markdown]
# to count the number of people who knows python we can use `.sum()` function. it counts True as 1 and flase as 0

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
# country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#AttributeError: 'SeriesGroupBy' object has no attribute 'str' 

# so we need to apply it

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).head(3)
# Out:
# Country
# Afghanistan     8
# Albania        23
# Algeria        40
# Name: LanguageWorkedWith, dtype: int64

# %% [markdown]
# This gives result for all country
#
# ---

# %% [markdown]
# to get the <mark>percentage</mark> of people each country who siad they know python.

# %%
country_respondents = df['Country'].value_counts()
country_respondents.head(3)
# Out:
# Country
# United States    20949
# India             9061
# Germany           5866
# Name: count, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python.head(3)
# Out:
# Country
# Afghanistan     8
# Albania        23
# Algeria        40
# Name: LanguageWorkedWith, dtype: int64

# %%
# # MY TEST
# ts = pd.DataFrame([country_respondents - country_uses_python])
# ts

# %% [markdown]
# to combine these two
#
# we can combine more than one series together with pandas `concat()` function

# %% [markdown]
# have to use `axis='columns'` because by default it concat rows

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns') #sort False by default now
python_df.head(3)
# Out:
#                count  LanguageWorkedWith
# Country
# United States  20949               10083
# India           9061                3105
# Germany         5866                2451

# %%
python_df.rename(columns={'count' : 'Total Respondents', 'LanguageWorkedWith': 'Knows Python'}, inplace=True)
python_df.head(3)
# Out:
#                Total Respondents  Knows Python
# Country
# United States              20949         10083
# India                       9061          3105
# Germany                     5866          2451

# %% [markdown]
# now to calculate the % we can create new column and put the result of calulation in it

# %%
python_df['Pct_Knows_Python'] = (python_df['Knows Python'] / python_df['Total Respondents']) * 100
python_df.head(3)
# Out:
#                Total Respondents  Knows Python  Pct_Knows_Python
# Country
# United States              20949         10083         48.131176
# India                       9061          3105         34.267741
# Germany                     5866          2451         41.783157

# %%
python_df.sort_values(by='Pct_Knows_Python', ascending=False, inplace=True)
python_df.head(11)
# Out:
#                        Total Respondents  Knows Python  Pct_Knows_Python
# Country
# Sao Tome and Principe                  1             1        100.000000
# Timor-Leste                            1             1        100.000000
# Dominica                               1             1        100.000000
# Niger                                  1             1        100.000000
# Turkmenistan                           7             6         85.714286
# Mauritania                             7             5         71.428571
# Guinea                                 3             2         66.666667
# Bahamas                                3             2         66.666667
# Guyana                                 3             2         66.666667
# Uganda                                72            47         65.277778
# Iceland                               49            30         61.224490

# %%
python_df.loc['Japan']
# Out:
# Total Respondents    391.000000
# Knows Python         182.000000
# Pct_Knows_Python      46.547315
# Name: Japan, dtype: float64

# %% [markdown]
# ---
# ---
# ---
