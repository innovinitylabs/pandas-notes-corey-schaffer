# %% [markdown]
# # 04 - Filtering - Using Conditionals to Filter Rows and Columns
#
# https://youtu.be/Lw2rlcxScZY?si=GV9Pm1IzeNSndh-p
#
# Notes by [Innovinitylabs](https://github.com/innovinitylabs)

# %%
import pandas as pd
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}
dft = pd.DataFrame(people)

# %% [markdown]
# to get everyone with last name Doe

# %% [markdown]
# we get only a `series` with yes or no

# %%
dft['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %% [markdown]
# so we are adding it to a variable for clarity and then later we can use it to filter and get the data we need

# %%
filt = (dft['last'] == 'Doe') # () added for clarity

# %%
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %% [markdown]
# we can put it directly in the brackets for dataframe  but for clarity we are adding it variable and use

# %%
dft[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %% [markdown]
# but its better to use `.loc` since we can also filter using column if needed

# %%
dft.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %% [markdown]
# #### AND OR Operator in pandas
# > AND = `&`
# > OR  = `|`

# %%
filt2 = (dft['last'] == 'Doe') & (dft['first'] == 'John')

# %%
dft.loc[filt2, 'email']
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %% [markdown]
# to negate the filter we use `~` (kinda like NOT)

# %%
dft.loc[~filt2, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %% [markdown]
# ### Survey Data

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent' )
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)

# %%
# pd.set_option('display.max_rows', 85)

# %%
df.head(1)
# Out:
#                                         MainBranch Hobbyist OpenSourcer  \
# Respondent
# 1           I am a student who is learning to code      Yes       Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
#
#                                         Employment         Country Student  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom      No
#
#                               EdLevel UndergradMajor  \
# Respondent
# 1           Primary/elementary school            NaN
#
#                                                      EduOther OrgSize DevType  \
# Respondent
# 1           Taught yourself a new language, framework, or ...     NaN     NaN
#
#            YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot  \
# Respondent
# 1                  4         10          NaN       NaN    NaN      NaN
#
# ...

# %%
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %% [markdown]
# To filter high salary and know what languages they know

# %%
filt_highsal = (df['ConvertedComp'] > 70000)

# %%
df.loc[filt_highsal, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['India', 'Germany']
country_filt = df['Country'].isin(countries)

# %%
# df[country_filt, ['LanguageWorkedWith', 'ConvertedComp'] ] this gives error
df.loc[country_filt, ['LanguageWorkedWith', 'ConvertedComp'] ]
# Out:
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# 10                              C#;Go;JavaScript;Python;R;SQL        13293.0
# 14                                                        C++        57060.0
# 15          Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...            NaN
# 36                                         Java;Kotlin;Python        20628.0
# ...                                                       ...            ...
# 80319       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...            NaN
# 83786                   HTML/CSS;JavaScript;Kotlin;TypeScript            NaN
# 83862       Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...            NaN
# 84299        HTML/CSS;Java;JavaScript;Python;Swift;TypeScript            NaN
# 86012           Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript            NaN
#
# [14927 rows x 2 columns]

# %% [markdown]
# #### String Methods Basics

# %% [markdown]
# language filter

# %%
lang_filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %% [markdown]
# we can use `.str.contains()` and give `na=False` for those columns that contains no values

# %%
df.loc[lang_filt, ['LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python            NaN
# 2                                         C++;HTML/CSS;Python            NaN
# 4                                         C;C++;C#;Python;SQL        61000.0
# 5                 C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA            NaN
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# ...                                                       ...            ...
# 84539       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...            NaN
# 85738         Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):            NaN
# 86566         Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):            NaN
# 87739                C;C++;HTML/CSS;JavaScript;PHP;Python;SQL            NaN
# 88212                              HTML/CSS;JavaScript;Python            NaN
#
# [36443 rows x 2 columns]
